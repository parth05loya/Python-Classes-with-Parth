# %% [markdown]
# <a href="https://colab.research.google.com/github/parth05loya/Python-Classes-with-Parth/blob/main/Class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string - "Hi, my name is Parth"
integer - 10
float - 10.5

# %%
a = "Hello"
b = "Rahul"
print(a)
print(b)
# Out:
# Hello
# Rahul

# %%
c = 100
d = 500
print(c + d)
# Out:
# 600

# %%
a = 100
b = 6
c = a/b
c
# Out:
# 16.666666666666668

# %%
#Indexing
place = 'united states'
place[0]
# Out:
# 'u'

# %%
place[1]
# Out:
# 'n'

# %%
place[-1]
# Out:
# 's'

# %%
place[-2]
# Out:
# 'e'

# %%
#String Slicing
place[3:6]
# Out:
# 'ted'

# %%
place[1:]
# Out:
# 'nited states'

# %%
place[:-1]
# Out:
# 'united state'

# %%
place[::3]
# Out:
# 'ut as'

# %%
place[::-2]
# Out:
# 'stt eiu'

# %%
#Concatenation
A = "United"
B = "States"
A+B
# Out:
# 'UnitedStates'

# %%
print("United %s" % "States")
# Out:
# United States

# %%
print(A+" "+B)
# Out:
# United States

# %%
print(A)
# Out:
# United

# %%
#Methods
print("I live in {}".format(A+B))
# Out:
# I live in UnitedStates

# %%
Name = "Parth"
Country = "India"
Learning = "Python"
statement = "Hi, my name is \"{}\". I am currently living in {}. I am learning {}".format(Name, Country, Learning)

# %%
statement
# Out:
# 'Hi, my name is "Parth". I am currently living in India. I am learning Python'

# %%
b = statement.split()

# %%
b
# Out:
# ['Hi,',
#  'my',
#  'name',
#  'is',
#  '"Parth".',
#  'I',
#  'am',
#  'currently',
#  'living',
#  'in',
#  'India.',
#  'I',
#  'am',
#  'learning',
#  'Python']

# %%
list2 = [2.5,3,7,1,2,0,-1,4]
list2.sort()
list2
# Out:
# [-1, 0, 1, 2, 2.5, 3, 4, 7]

# %%
list2.reverse()
list2
# Out:
# [7, 4, 3, 2.5, 2, 1, 0, -1]

# %%
list2[2:]
# Out:
# [3, 2.5, 2, 1, 0, -1]

# %%
list2.append(5)
list2
# Out:
# [7, 4, 3, 2.5, 2, 1, 0, -1, 5]

# %%
list2.pop()
list2
# Out:
# [4, 3, 2.5, 2, 1, 0, -1, 5]

# %%
list2.pop(-1)
list2
# Out:
# [4, 3, 2.5, 2, 1, 0, -1]
